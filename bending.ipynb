# %%
from netgen.occ import *
from ngsolve import *
from ngsolve.webgui import Draw
from ngsolve.meshes import MakeStructured3DMesh
from utility_functions import get_polar_decomposition, Anti

import numpy as np
import time
import traceback
import os
import matplotlib.pylab as plt

# %%
use_autodiff = False
use_legacy = False
ngsglobals.code_uses_equivalence_keys=True
ngsglobals.code_uses_tensors=True
SetNumThreads(16)
draw_angle = { "euler_angles" : [20,-40,0] }

# %%
# --- Helper functions
def F(u):
    return Grad(u) + Id(3)

def R(r):
    r0 = r[0]
    r1 = r[1]
    r2 = r[2]
    
    cosr0 = cos(r0)
    cosr1 = cos(r1)
    cosr2 = cos(r2)
    
    sinr0 = sin(r0)
    sinr1 = sin(r1)
    sinr2 = sin(r2)
    return CF ( ( cosr1*cosr2, sinr0*sinr1*cosr2 - sinr2*cosr0,  sinr0*sinr2 + sinr1*cosr0*cosr2,
                sinr2*cosr1, sinr0*sinr1*sinr2 + cosr0*cosr2, -sinr0*cosr2 + sinr1*sinr2*cosr0,
                -sinr1     , sinr0*cosr1                    , cosr0*cosr1                      ), dims = (3,3) )

def CurlR(r):
    r0 = r[0]
    r1 = r[1]
    r2 = r[2]
    
    cosr0 = cos(r0)
    cosr1 = cos(r1)
    cosr2 = cos(r2)
    
    sinr0 = sin(r0)
    sinr1 = sin(r1)
    sinr2 = sin(r2)
    
    Dr = Grad(r)
    Drx = CF( (Dr[0,0],Dr[0,1],Dr[0,2]), dims=(3,1) )
    Dry = CF( (Dr[1,0],Dr[1,1],Dr[1,2]), dims=(3,1) )
    Drz = CF( (Dr[2,0],Dr[2,1],Dr[2,2]), dims=(3,1) )
    
    dRz = CF( (sinr2*cosr1, sinr0*sinr1*sinr2 + cosr0*cosr2, -sinr0*cosr2 + sinr1*sinr2*cosr0, -cosr1*cosr2, -sinr0*sinr1*cosr2 + sinr2*cosr0, -sinr0*sinr2 - sinr1*cosr0*cosr2, 0, 0, 0), dims = (3,3) )
    dRy = CF( (sinr1*cosr2, -sinr0*cosr1*cosr2, -cosr0*cosr1*cosr2, sinr1*sinr2, -sinr0*sinr2*cosr1, -sinr2*cosr0*cosr1, cosr1, sinr0*sinr1, sinr1*cosr0), dims = (3,3) )
    dRx = CF( (0, -sinr0*sinr2 - sinr1*cosr0*cosr2, sinr0*sinr1*cosr2 - sinr2*cosr0, 0, sinr0*cosr2 - sinr1*sinr2*cosr0, sinr0*sinr1*sinr2 + cosr0*cosr2, 0, -cosr0*cosr1, sinr0*cosr1), dims = (3,3) )
    
    return CF(dRz * Anti(Drz) + dRy * Anti(Dry) + dRx * Anti(Drx))

# %%
# --- Geometry
L = 20
b = 10
h = 1
n_refin = 1
mesh = MakeStructured3DMesh(
        hexes=False,
        nx=1 * (2**(n_refin)),
        ny=1 + (n_refin-1),
        nz=1* (2**(n_refin-1)),
        mapping=lambda x, y, z: (L*x,h*(y-1/2),b/2*(z)),
        secondorder=False
    )   
mesh.Refine()
Draw(mesh, **draw_angle)
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'camera': {'euler_angles': […
# BaseWebGuiScene

# %%
# --- Function spaces
# Displacement and microrotation:
order = 2
fesU = VectorH1(mesh, order=order, dirichlet="back", dirichletz="bottom")
fesR = VectorH1(mesh, order=order, dirichlet="back", dirichletx="bottom", dirichlety="bottom")
# fesR.SetOrder(TET, 4)
# fesR.Update()

fes = fesU * fesR
(u,r), (du,dr) = fes.TnT()

# Rotation tensor
fesZ = HCurl(mesh, order=1, type1=False, discontinuous=True)**3
RZ = Interpolate(R(r), fesZ, bonus_intorder=4)
polarRZ, _ = get_polar_decomposition(RZ,use_legacy=use_legacy, autodiff=use_autodiff)

# %%
# --- Material parameters
E = Parameter( 1200 )
nu = Parameter( 0.3 )
lt = Parameter( 0.38 )
lb = Parameter( 0.5 )
psi = Parameter( 1.1 )
Lc = Parameter( 1 )
muc_factor = 1e4

mu = G = E/(2*(1+nu))
lam = - G*(E-2*G)/(E-3*G)
muc = muc_factor*G
alpha1 = 2*lt**2/Lc**2
alpha2 = (8*lb**2-2*lt**2)/Lc**2
alpha3 = 4*lt**2*(3-2*psi)/psi/Lc**2

# --- Elastic energy
def sym(A):
    """
    Use instead of Sym() of NGSolve to avoid problem with code_uses_equivalence_keys flag.
    """
    return 1/2 * (A + A.trans)

def skw(A):
    """
    Use instead of Skw() of NGSolve to avoid problem with code_uses_equivalence_keys flag.
    """
    return 1/2 * (A - A.trans)

def C(m):
    return lam * Trace(m) * Id(3) + 2*mu * m

def PSI(U, A):
    return 1/2 * (
            InnerProduct(sym(U) - Id(3), C(sym(U) - Id(3)))
        + 2*muc*InnerProduct(skw(U), skw(U))
        + mu*Lc**2 * (
            alpha1*InnerProduct(Deviator(sym(A)),Deviator(sym(A)))
            + alpha2*InnerProduct(skw(A),skw(A))
            + alpha3/3 * Trace(A)**2
        )
        #+ mu*Lc**2 * (InnerProduct(A,A))
        )

# %%
# --- Strain measures
# Stretch tensor U=R.trans*F
U = CF(R(r).trans*F(u))
#U = CF(RZ.trans*F(u))
#U = CF(polarRZ.trans*F(u))

# Dislocation tensor A = R.trans*Curl(R)
A = CF(R(r).trans*CurlR(r))

# --- Set up bilinear form
a = BilinearForm(fes)
ts = time.time()
#a += Variation ( PSI(U, A).Compile(realcompile=True, wait=True, keep_files=True) * dx )
a += Variation ( PSI(U, A).Compile() * dx )
te = time.time()
print (f"Compile took {te-ts} seconds")

# Set up load
force = 40
loadfactor = Parameter(1)
traction = loadfactor * force / b / h / 2 * CF((-1,1,0))
a += - (traction*du)*ds("front")
# Out:
# Warning: using default CalcEquivalenceKey for ngfem::ProxyFunction
# Warning: using default CalcEquivalenceKey for ngfem::VectorialCoefficientFunction
# Warning: using default CalcEquivalenceKey for ngfem::ProxyFunction
# Warning: using default CalcEquivalenceKey for ngfem::ParameterCoefficientFunction<double>
# Warning: using default CalcEquivalenceKey for ngfem::ParameterCoefficientFunction<double>
# Warning: using default CalcEquivalenceKey for ngfem::ParameterCoefficientFunction<double>
# Warning: using default CalcEquivalenceKey for ngfem::ParameterCoefficientFunction<double>
# Warning: using default CalcEquivalenceKey for ngfem::VectorialCoefficientFunction
# Warning: using default CalcEquivalenceKey for ngfem::VectorialCoefficientFunction
# Warning: using default CalcEquivalenceKey for ngfem::ProxyFunction
# Warning: using default CalcEquivalenceKey for ngfem::VectorialCoefficientFunction
# Warning: using default CalcEquivalenceKey for ngfem::VectorialCoefficientFunction
# Warning: using default CalcEquivalenceKey for ngfem::VectorialCoefficientFunction
# Warning: using default CalcEquivalenceKey for ngfem::VectorialCoefficientFunction
# Warning: using default CalcEquivalenceKey for ngfem::VectorialCoefficientFunction
# Warning: using default CalcEquivalenceKey for ngfem::VectorialCoefficientFunction
# Warning: using default CalcEquivalenceKey for ngfem::VectorialCoefficientFunction
# Warning: using default CalcEquivalenceKey for ngfem::VectorialCoefficientFunction
# Warning: using default CalcEquivalenceKey for ngfem::ParameterCoefficientFunction<double>
# Warning: using default CalcEquivalenceKey for ngfem::ParameterCoefficientFunction<double>
# Compile took 0.007853507995605469 seconds

# %%
# --- Define grid function
gfu = GridFunction(fes)
print(f"There are {gfu.space.ndof} DoFs")
# Out:
# There are 1350 DoFs

# %%
# --- Solve problem with adaptive load stepping
steps = 40
max_load = 1.0
loadvalue = 0.0
load_step = 1.0 / steps
min_load_step = 1e-5
max_load_step = 0.5
reduce_factor = 0.5
increase_factor = 1.1

scene = Draw(gfu.components[0], deformation=True, **draw_angle)
step = 0
while loadvalue < max_load - 1e-12:
    try:
        loadvalue_next = min(loadvalue + load_step, max_load)
        loadfactor.Set(loadvalue_next)

        print(f" --- Step {step+1}: target load {loadvalue_next:.6f} --- ", flush=True)

        old_gfu = gfu.vec.CreateVector()  # deep copy to restore on failure
        old_gfu.data = gfu.vec

        with TaskManager():
            start = time.perf_counter()
            converged, newton_iterations = solvers.Newton(a, gfu, maxerr=1e-9,
                                                        printing=True, maxit=15, dampfactor=1)
            end = time.perf_counter()

        if converged == -1:
            raise RuntimeError("Computation did not converge")

        print(f"Execution time: {end - start:.3f}s with {newton_iterations} Newton iterations",
            flush=True)
        scene.Redraw()
        # Step succeeded - accept and maybe enlarge next step
        loadvalue = loadvalue_next
        step += 1
        load_step = min(load_step * increase_factor, max_load_step)
    except Exception as e:
        print(f"Step {step+1} failed (load={loadvalue_next:.6f}). Reducing step...", flush=True)
        gfu.vec.data = old_gfu  # restore previous converged state
        load_step *= reduce_factor
        if load_step < min_load_step:
            print("Load step became too small — stopping.")
            break
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'camera': {'euler_angles': […
#  --- Step 1: target load 0.025000 ---
# Newton iteration  0
# err =  0.2606188180105982
# Newton iteration  1
# err =  0.4795903439115777
# Newton iteration  2
# err =  0.020311338670408435
# Newton iteration  3
# err =  0.001150792736970117
# Newton iteration  4
# err =  1.1136807678028342e-06
# Newton iteration  5
# err =  7.59204738294021e-12
# Execution time: 2.371s with 6 Newton iterations
#  --- Step 2: target load 0.052500 ---
# Newton iteration  0
# err =  0.2938821343870637
# Newton iteration  1
# err =  0.6253422310074616
# Newton iteration  2
# err =  0.018746537359958886
# Newton iteration  3
# err =  0.0009948262021388125
# Newton iteration  4
# err =  2.3512286906621622e-06
# Newton iteration  5
# err =  9.149564927794407e-11
# Execution time: 2.795s with 6 Newton iterations
#  --- Step 3: target load 0.082750 ---
# Newton iteration  0
# err =  0.331916829262813
# Newton iteration  1
# err =  0.8192917621009183
# Newton iteration  2
# err =  0.03522313337000466
# Newton iteration  3
# err =  0.0020693625417955728
# Newton iteration  4
# err =  2.2151554311736416e-05
# Newton iteration  5
# err =  8.48163338485868e-09
# Newton iteration  6
# err =  5.423627674037835e-13
# Execution time: 2.996s with 7 Newton iterations
#  --- Step 4: target load 0.116025 ---
# Newton iteration  0
# err =  0.3753592001931646
# Newton iteration  1
# err =  1.0778127221581764
# Newton iteration  2
# err =  0.08074369786011974
# Newton iteration  3
# err =  0.007543523834488138
# Newton iteration  4
# err =  0.000659562736293549
# Newton iteration  5
# err =  8.366618795221278e-06
# Newton iteration  6
# err =  1.4158744334006746e-09
# Newton iteration  7
# err =  8.964402872882877e-13
# Execution time: 3.672s with 8 Newton iterations
#  --- Step 5: target load 0.152628 ---
# Newton iteration  0
# err =  0.4248067564032525
# Newton iteration  1
# err =  1.4239263502018906
# Newton iteration  2
# err =  0.272964150937696
# Newton iteration  3
# err =  0.2829778772685545
# Newton iteration  4
# err =  0.09323950898773355
# Newton iteration  5
# err =  0.07628987374105155
# Newton iteration  6
# err =  0.038470096505748556
# Newton iteration  7
# err =  0.009898966791180575
# Newton iteration  8
# err =  0.0013069661062840826
# Newton iteration  9
# err =  2.2627431846818446e-05
# Newton iteration  10
# err =  4.852147929606751e-09
# Newton iteration  11
# err =  1.0338724181467798e-12
# Execution time: 5.438s with 12 Newton iterations
#  --- Step 6: target load 0.192890 ---
# Newton iteration  0
# err =  0.4806891664099276
# Newton iteration  1
# err =  1.836039188548803
# Newton iteration  2
# err =  1.104021035765233
# Newton iteration  3
# err =  0.5893746812465652
# Newton iteration  4
# err =  1.003042202899659
# Newton iteration  5
# err =  0.35267531717917017
# Newton iteration  6
# err =  0.2758651855911345
# Newton iteration  7
# err =  0.46165548440101545
# Newton iteration  8
# err =  13.96135517491114
# Newton iteration  9
# err =  1.5586744061751014
# Newton iteration  10
# err =  29.99013756989889
# Newton iteration  11
# err =  1.7238581834531568
# Newton iteration  12
# err =  38.92159793685984
# Newton iteration  13
# err =  4.368540587802448
# Newton iteration  14
# err =  237.61159226475584
# Warning: Newton might not converge! Error =  237.61159226475584
# Step 6 failed (load=0.192890). Reducing step...
#  --- Step 6: target load 0.172759 ---
# Newton iteration  0
# err =  0.2403445827184947
# Newton iteration  1
# err =  0.44954794037845064
# Newton iteration  2
# err =  0.03147931067785394
# Newton iteration  3
# err =  0.0017990377449382897
# Newton iteration  4
# err =  3.4598637922333915e-06
# Newton iteration  5
# err =  6.513740385810225e-11
# Execution time: 2.749s with 6 Newton iterations
#  --- Step 7: target load 0.194903 ---
# Newton iteration  0
# err =  0.2680972071613708
# Newton iteration  1
# err =  0.5643746774573507
# Newton iteration  2
# err =  0.015601506900214125
# Newton iteration  3
# err =  0.0004970602007414373
# Newton iteration  4
# err =  3.9378409371290676e-07
# Newton iteration  5
# err =  3.1066002452640964e-12
# Execution time: 2.667s with 6 Newton iterations
#  --- Step 8: target load 0.219262 ---
# Newton iteration  0
# err =  0.29903007997440045
# Newton iteration  1
# err =  0.7077199550242121
# Newton iteration  2
# err =  0.024516144918076622
# Newton iteration  3
# err =  0.0007631438953604622
# Newton iteration  4
# err =  2.0650903128061856e-06
# Newton iteration  5
# err =  7.418943579778192e-11
# Execution time: 2.765s with 6 Newton iterations
#  --- Step 9: target load 0.246057 ---
# Newton iteration  0
# err =  0.33333992951911745
# Newton iteration  1
# err =  0.8848618741063234
# Newton iteration  2
# err =  0.04437743761024865
# Newton iteration  3
# err =  0.0018671837442192291
# Newton iteration  4
# err =  1.875996046867553e-05
# Newton iteration  5
# err =  6.167678058575159e-09
# Newton iteration  6
# err =  1.7805084051073893e-12
# Execution time: 3.495s with 7 Newton iterations
#  --- Step 10: target load 0.275532 ---
# Newton iteration  0
# err =  0.371118663427961
# Newton iteration  1
# err =  1.1006185308983034
# Newton iteration  2
# err =  0.09114303647683437
# Newton iteration  3
# err =  0.007552248766696783
# Newton iteration  4
# err =  0.0006895941820195206
# Newton iteration  5
# err =  8.933753518116036e-06
# Newton iteration  6
# err =  1.595552602570174e-09
# Newton iteration  7
# err =  2.3016783437354153e-12
# Execution time: 3.757s with 8 Newton iterations
#  --- Step 11: target load 0.307953 ---
# Newton iteration  0
# err =  0.4122868673213045
# Newton iteration  1
# err =  1.3589690491827167
# Newton iteration  2
# err =  0.2206896488464689
# Newton iteration  3
# err =  0.8939050107677592
# Newton iteration  4
# err =  0.3367855503576239
# Newton iteration  5
# err =  2.7587706109970536
# Newton iteration  6
# err =  0.35555998489910634
# Newton iteration  7
# err =  3.8707462586082584
# Newton iteration  8
# err =  0.4707707044710704
# Newton iteration  9
# err =  10.944505068072926
# Newton iteration  10
# err =  0.3057777788151497
# Newton iteration  11
# err =  16.832682068611415
# Newton iteration  12
# err =  3.0224754764844826
# Newton iteration  13
# err =  38.63713065521066
# Newton iteration  14
# err =  24.126935406197834
# Warning: Newton might not converge! Error =  24.126935406197834
# Step 11 failed (load=0.307953). Reducing step...
#  --- Step 11: target load 0.291742 ---
# Newton iteration  0
# err =  0.20614343199813467
# Newton iteration  1
# err =  0.3293397728607871
# Newton iteration  2
# err =  0.004768399119689519
# Newton iteration  3
# err =  3.5973630825447e-05
# Newton iteration  4
# err =  2.253733131449622e-10
# Execution time: 2.302s with 5 Newton iterations
#  --- Step 12: target load 0.309574 ---
# Newton iteration  0
# err =  0.22763674276685752
# Newton iteration  1
# err =  0.39953593004370863
# Newton iteration  2
# err =  0.008252227269727113
# Newton iteration  3
# err =  0.00010831192923554012
# Newton iteration  4
# err =  4.385049091683543e-09
# Newton iteration  5
# err =  2.491007658055264e-12
# Execution time: 2.779s with 6 Newton iterations
#  --- Step 13: target load 0.329190 ---
# Newton iteration  0
# err =  0.2511386962219369
# Newton iteration  1
# err =  0.4825760580213352
# Newton iteration  2
# err =  0.07347598645640945
# Newton iteration  3
# err =  0.007953218784558434
# Newton iteration  4
# err =  0.00020875005220895483
# Newton iteration  5
# err =  7.088460251342737e-07
# Newton iteration  6
# err =  5.306627066792258e-12
# Execution time: 3.162s with 7 Newton iterations
#  --- Step 14: target load 0.350766 ---
# Newton iteration  0
# err =  0.27670844984566806
# Newton iteration  1
# err =  0.5798682737176913
# Newton iteration  2
# err =  0.017524789837586752
# Newton iteration  3
# err =  0.00036661308328686
# Newton iteration  4
# err =  3.5087534133768234e-08
# Newton iteration  5
# err =  3.747515956169884e-12
# Execution time: 2.826s with 6 Newton iterations
#  --- Step 15: target load 0.374501 ---
# Newton iteration  0
# err =  0.3043536186015446
# Newton iteration  1
# err =  0.6917074622404972
# Newton iteration  2
# err =  0.024304184694574012
# Newton iteration  3
# err =  0.0008452399803377353
# Newton iteration  4
# err =  5.421058016332489e-07
# Newton iteration  5
# err =  5.105454597611006e-12
# Execution time: 2.876s with 6 Newton iterations
#  --- Step 16: target load 0.400608 ---
# Newton iteration  0
# err =  0.3340146951567098
# Newton iteration  1
# err =  0.8177515666590524
# Newton iteration  2
# err =  0.03740495885369064
# Newton iteration  3
# err =  0.0019524101998508253
# Newton iteration  4
# err =  5.4046049168937345e-06
# Newton iteration  5
# err =  3.7774212936094834e-10
# Execution time: 2.712s with 6 Newton iterations
#  --- Step 17: target load 0.429327 ---
# Newton iteration  0
# err =  0.36555265594166136
# Newton iteration  1
# err =  0.9562681793987904
# Newton iteration  2
# err =  0.06010602369932804
# Newton iteration  3
# err =  0.004440745420029726
# Newton iteration  4
# err =  4.125648148988251e-05
# Newton iteration  5
# err =  1.6684557170245534e-08
# Newton iteration  6
# err =  4.696868417912138e-12
# Execution time: 3.052s with 7 Newton iterations
#  --- Step 18: target load 0.460917 ---
# Newton iteration  0
# err =  0.3987442583417437
# Newton iteration  1
# err =  1.103980761272042
# Newton iteration  2
# err =  0.1012519778164892
# Newton iteration  3
# err =  0.010157415742023706
# Newton iteration  4
# err =  0.0004255655783336695
# Newton iteration  5
# err =  5.484872633522545e-07
# Newton iteration  6
# err =  5.655439139415329e-12
# Execution time: 3.053s with 7 Newton iterations
#  --- Step 19: target load 0.495667 ---
# Newton iteration  0
# err =  0.4332898146390758
# Newton iteration  1
# err =  1.2562593896813803
# Newton iteration  2
# err =  0.18533769970234942
# Newton iteration  3
# err =  0.05463708540044188
# Newton iteration  4
# err =  0.03880611611979456
# Newton iteration  5
# err =  0.0031853798659446366
# Newton iteration  6
# err =  0.00013489145057673068
# Newton iteration  7
# err =  2.2254073136463088e-08
# Newton iteration  8
# err =  5.0026713482343665e-12
# Execution time: 4.273s with 9 Newton iterations
#  --- Step 20: target load 0.533891 ---
# Newton iteration  0
# err =  0.4688360466238323
# Newton iteration  1
# err =  1.408632794857668
# Newton iteration  2
# err =  0.3772398297458659
# Newton iteration  3
# err =  0.21227293050197418
# Newton iteration  4
# err =  0.13342557156574333
# Newton iteration  5
# err =  0.06572151967260899
# Newton iteration  6
# err =  0.03089202467168558
# Newton iteration  7
# err =  0.006291445289081059
# Newton iteration  8
# err =  0.0003522815048734523
# Newton iteration  9
# err =  1.4591054396283992e-06
# Newton iteration  10
# err =  1.82836467520843e-11
# Execution time: 5.469s with 11 Newton iterations
#  --- Step 21: target load 0.575938 ---
# Newton iteration  0
# err =  0.5050130990032023
# Newton iteration  1
# err =  1.5722834763836264
# Newton iteration  2
# err =  1.6714903372105123
# Newton iteration  3
# err =  7.163748816376485
# Newton iteration  4
# err =  8.19618457225288
# Newton iteration  5
# err =  19.687545407714595
# Newton iteration  6
# err =  20.674557947508013
# Newton iteration  7
# err =  108.49732166469329
# Newton iteration  8
# err =  25.13381558595087
# Newton iteration  9
# err =  444.71946965098664
# Newton iteration  10
# err =  214.91385315271262
# Newton iteration  11
# err =  854.7369715497061
# Newton iteration  12
# err =  2237.8958591217583
# Newton iteration  13
# err =  11022.069152842301
# Newton iteration  14
# err =  63637.99125322629
# Warning: Newton might not converge! Error =  63637.99125322629
# Step 21 failed (load=0.575938). Reducing step...
#  --- Step 21: target load 0.554915 ---
# Newton iteration  0
# err =  0.25250655047500575
# Newton iteration  1
# err =  0.37168771407091494
# Newton iteration  2
# err =  0.007403309974381965
# Newton iteration  3
# err =  0.00028501750765680167
# Newton iteration  4
# err =  3.932953016361782e-08
# Newton iteration  5
# err =  4.803529854578256e-12
# Execution time: 2.914s with 6 Newton iterations
#  --- Step 22: target load 0.578041 ---
# Newton iteration  0
# err =  0.2742999026597829
# Newton iteration  1
# err =  0.42475240202992837
# Newton iteration  2
# err =  0.01080689549728592
# Newton iteration  3
# err =  0.00043386540382634034
# Newton iteration  4
# err =  1.1854844527942043e-07
# Newton iteration  5
# err =  7.535266895739661e-12
# Execution time: 2.844s with 6 Newton iterations
#  --- Step 23: target load 0.603479 ---
# Newton iteration  0
# err =  0.2974171247415382
# Newton iteration  1
# err =  0.48173403865188474
# Newton iteration  2
# err =  0.021272146872273467
# Newton iteration  3
# err =  0.0007016602142624959
# Newton iteration  4
# err =  4.728822424253549e-07
# Newton iteration  5
# err =  6.69726506001424e-12
# Execution time: 2.881s with 6 Newton iterations
#  --- Step 24: target load 0.631461 ---
# Newton iteration  0
# err =  0.321832748208054
# Newton iteration  1
# err =  0.5417195428351522
# Newton iteration  2
# err =  0.08913653897793512
# Newton iteration  3
# err =  0.01039023773096156
# Newton iteration  4
# err =  0.00030240737304091335
# Newton iteration  5
# err =  9.766121847538278e-07
# Newton iteration  6
# err =  1.3125792359428148e-11
# Execution time: 3.281s with 7 Newton iterations
#  --- Step 25: target load 0.662242 ---
# Newton iteration  0
# err =  0.3475078056271955
# Newton iteration  1
# err =  0.6042526876994273
# Newton iteration  2
# err =  0.027369374671548326
# Newton iteration  3
# err =  0.0015585190566739999
# Newton iteration  4
# err =  3.236899906116908e-06
# Newton iteration  5
# err =  1.1902245186744486e-10
# Execution time: 2.718s with 6 Newton iterations
#  --- Step 26: target load 0.696100 ---
# Newton iteration  0
# err =  0.37439288769285406
# Newton iteration  1
# err =  0.6678044768141245
# Newton iteration  2
# err =  0.02861004252099463
# Newton iteration  3
# err =  0.0022637846214677414
# Newton iteration  4
# err =  3.1536376516826743e-06
# Newton iteration  5
# err =  9.960206577885417e-11
# Execution time: 2.669s with 6 Newton iterations
#  --- Step 27: target load 0.733344 ---
# Newton iteration  0
# err =  0.4024323722179808
# Newton iteration  1
# err =  0.7311957190218454
# Newton iteration  2
# err =  0.034521798366420754
# Newton iteration  3
# err =  0.003256113979385619
# Newton iteration  4
# err =  3.086633178723448e-06
# Newton iteration  5
# err =  3.239459613379583e-11
# Execution time: 3.061s with 6 Newton iterations
#  --- Step 28: target load 0.774313 ---
# Newton iteration  0
# err =  0.4315694229580801
# Newton iteration  1
# err =  0.7930927411986792
# Newton iteration  2
# err =  0.04289138659831231
# Newton iteration  3
# err =  0.004602094732082231
# Newton iteration  4
# err =  5.647407198742827e-06
# Newton iteration  5
# err =  1.1262558418127295e-10
# Execution time: 2.785s with 6 Newton iterations
#  --- Step 29: target load 0.819379 ---
# Newton iteration  0
# err =  0.46175118060915865
# Newton iteration  1
# err =  0.8521846947642268
# Newton iteration  2
# err =  0.05352878597344373
# Newton iteration  3
# err =  0.006401776416971789
# Newton iteration  4
# err =  2.132094314123397e-05
# Newton iteration  5
# err =  3.6376439609560555e-09
# Newton iteration  6
# err =  9.036905664493372e-12
# Execution time: 3.239s with 7 Newton iterations
#  --- Step 30: target load 0.868951 ---
# Newton iteration  0
# err =  0.49293351436078225
# Newton iteration  1
# err =  0.9072717596135192
# Newton iteration  2
# err =  0.06656360353242544
# Newton iteration  3
# err =  0.008765175191725056
# Newton iteration  4
# err =  6.36540710809627e-05
# Newton iteration  5
# err =  3.533229414094899e-08
# Newton iteration  6
# err =  1.1581024163895004e-11
# Execution time: 3.089s with 7 Newton iterations
#  --- Step 31: target load 0.923480 ---
# Newton iteration  0
# err =  0.5250849363122656
# Newton iteration  1
# err =  0.9573370205627746
# Newton iteration  2
# err =  0.08216558476170671
# Newton iteration  3
# err =  0.011799911325093617
# Newton iteration  4
# err =  0.00015855173116212514
# Newton iteration  5
# err =  2.093055513339501e-07
# Newton iteration  6
# err =  1.2247634319259284e-11
# Execution time: 2.889s with 7 Newton iterations
#  --- Step 32: target load 0.983463 ---
# Newton iteration  0
# err =  0.5581891638086669
# Newton iteration  1
# err =  1.0015941584431975
# Newton iteration  2
# err =  0.1004361836265261
# Newton iteration  3
# err =  0.015588520043398045
# Newton iteration  4
# err =  0.00034617827480661967
# Newton iteration  5
# err =  8.968978938286938e-07
# Newton iteration  6
# err =  1.0978015467890872e-11
# Execution time: 3.133s with 7 Newton iterations
#  --- Step 33: target load 1.000000 ---
# Newton iteration  0
# err =  0.1484413659759979
# Newton iteration  1
# err =  0.06265363378948073
# Newton iteration  2
# err =  0.00128006600945029
# Newton iteration  3
# err =  2.5993283944821563e-06
# Newton iteration  4
# err =  1.4646843026304288e-11
# Execution time: 2.233s with 5 Newton iterations

# %%
# Extract solution from gridfunction
u_sol = gfu.components[0]
r_sol = gfu.components[1]
F_sol = F(u_sol)

# --- Define name of test:
test_name = "bending"
os.makedirs("results", exist_ok=True)
filename = os.path.join("results", test_name)
vtk = VTKOutput(mesh,coefs=[u_sol, r_sol, F_sol],names=["u","r","F"],filename=os.path.join("results", "bending"),subdivision=0)
vtk.Do()
# Out:
# WebGuiWidget(layout=Layout(height='500px', width='100%'), value={'gui_settings': {'camera': {'euler_angles': […
# BaseWebGuiScene
